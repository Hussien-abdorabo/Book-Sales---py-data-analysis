# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sweetviz as sw

# %%
# %matplotlib inline

# %%
df = pd.read_csv("Books_Data_Clean.csv")

# %%
df.head()
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   object
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# ...

# %%
df.describe()
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# ...

# %%
df = df[df['Publishing Year'] > 1900]

# %%
df.describe(include = 'object')
# Out:
#          Book Name        Author language_code Author_Rating          genre  \
# count          988          1009           960          1009           1009
# unique         987           680             8             4              4
# top     Persepolis  Stephen King           eng  Intermediate  genre fiction
# freq             2            29           682           582            775
#
#                             Publisher
# count                             1009
# unique                               9
# top     Amazon Digital Services,  Inc.
# freq                               570

# %%
df.isna().sum()
# Out:
# index                   0
# Publishing Year         0
# Book Name              21
# Author                  0
# language_code          49
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
df.dropna(subset='Book Name',inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# index                  988
# Publishing Year        101
# Book Name              987
# Author                 669
# language_code            8
# Author_Rating            4
# Book_average_rating    133
# Book_ratings_count     983
# genre                    4
# gross sales            774
# publisher revenue      570
# sale price             143
# sales rank             818
# Publisher                9
# units sold             470
# dtype: int64

# %%
plt.hist(df['Publishing Year'],bins = 20)
plt.xlabel('Publishing Year')
plt.ylabel('Frequency')
plt.title('Distributions of Publishing year')
plt.show()

# %%
df['genre'].value_counts().plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Number of books')
plt.title('number of book in each genre')
# Out:
# Text(0.5, 1.0, 'number of book in each genre')

# %%
df.groupby('Author')['Book_average_rating'].mean().sort_values(ascending = False).head()
# Out:
# Author
# Bill Watterson                  4.650
# Bill Watterson, G.B. Trudeau    4.610
# J.R.R. Tolkien                  4.590
# George R.R. Martin              4.560
# Sarah J. Maas                   4.526
# Name: Book_average_rating, dtype: float64

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
sns.boxplot(x="genre" ,y="Book_ratings_count", data =df)
plt.xlabel("Genre")
plt.ylabel("Books_Rating_Cont")
plt.title("Box Plot of Number of Book raing Count for each Genre")
plt.show()

# %%
plt.scatter(df['sale price'], df['units sold'])
plt.xlabel(" Sale Price")
plt.ylabel(" units Sold")
plt.title("Scatter plot for sale price vs units sold")
# Out:
# Text(0.5, 1.0, 'Scatter plot for sale price vs units sold')

# %%
langauge_counts = df["language_code"].value_counts().sort_values(ascending= False)

# %%
plt.pie(langauge_counts , labels = langauge_counts.index, startangle=90, autopct="%1.1f%%")
plt.title("pie")
plt.show()

# %%
df.groupby("Publisher ")["publisher revenue"].sum().sort_values(ascending = False).head()
# Out:
# Publisher
# Penguin Group (USA) LLC           191581.104
# Random House LLC                  174956.244
# Amazon Digital Services,  Inc.    141767.772
# HarperCollins Publishers          121769.814
# Hachette Book Group               107410.968
# Name: publisher revenue, dtype: float64

# %%
df.groupby('language_code').size().sort_values(ascending = False)
# Out:
# language_code
# eng      670
# en-US    226
# en-GB     29
# en-CA      7
# fre        4
# ara        2
# spa        2
# nl         1
# dtype: int64

# %%
plt.scatter(df["Book_average_rating"],df['Book_ratings_count'])
plt.xlabel("Book_average_rating")
plt.ylabel("Book_ratings_count")
plt.title("scatter plot for Book_average_rating vs Book_ratings_count")
# Out:
# Text(0.5, 1.0, 'scatter plot for Book_average_rating vs Book_ratings_count')

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
total_gross_by_author = df.groupby("Author")["gross sales"].sum().head(10)

# %%
total_gross_by_author.sort_values(ascending=False).plot(kind="bar")
plt.xlabel("Author")
plt.ylabel("gross sales")
plt.title(" bar plot for gross sales for each author")
# Out:
# Text(0.5, 1.0, ' bar plot for gross sales for each author')
